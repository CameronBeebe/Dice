# %%
from Dice_Game import *

# %%
Game = Dice_Game(players = 4)

# %%
Game.play_game()
# Out:
# PLAYING GAME
# lets goooo!
# SHAKING
# I, Player_1 shook the dice: [5, 1, 1, 5, 1, 1]
# BEGIN DETECTING KEEPABLES
# set_of_three 1
# keepable dice faces after adding three of a kinds: [[1, 1, 1]]
# keepable dice faces after adding ones and fives: [[1, 1, 1], 5, 1, 1, 5, 1, 1]
# total keepable list of dice faces: [[1, 1, 1], 5, 1, 1, 5, 1, 1]
# total keepable list of dice faces: [[1, 1, 1], 5, 1, 1, 5, 1, 1]
# ALL COUNTERS.  BRING EM BACK!  NEED FUNCTION HERE!!!!
# BEGIN KEEPING DICE
# kept dice faces: [5]
# dice still to shake faces: [1, 1, 5, 1, 1]
# still to shake faces: [1, 1, 5, 1, 1]
# KEPT: [5]
# SCORING
# SINGLE 5 SCORES 50
# SCORE: 50
# FIRST JUNCTION
# On turn 1 shake 1 , I, Player_1 kept [5] and my total kept dice is [5]
# bringing back from first junction.............
# keep 'em rollin'!
# kept so far: [5]
# SHAKING
# I, Player_1 shook the dice: [4, 6, 5, 5, 2, 1]
# shake: [4, 6, 5, 5, 2, 1]
# BEGIN DETECTING KEEPABLES
# ...
